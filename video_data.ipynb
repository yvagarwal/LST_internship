# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Rendered/RB_103_data.csv')

# %%
data
# Out:
#       nose_x  nose_y      nose_z  left_eye_inner_x  left_eye_inner_y  \
# 0       1679     441 -240.975666              1698               427
# 1       1676     436 -323.348408              1696               421
# 2       1668     430 -339.960938              1689               418
# 3       1665     423 -319.936438              1684               411
# 4       1666     424 -333.636360              1684               410
# ...      ...     ...         ...               ...               ...
# 6283     638     394 -356.099482               645               373
# 6284     637     394 -352.372856               644               374
# 6285     636     395 -359.186354               643               374
# 6286     636     395 -347.892809               643               374
# 6287     636     395 -425.984087               643               374
#
#       left_eye_inner_z  left_eye_x  left_eye_y  left_eye_z  left_eye_outer_x  \
# ...

# %%
df = pd.get_dummies(data["label"])

# %%
df = df.drop(['sitting'], axis=1)
df
# Out:
#       standing
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 6283         0
# 6284         1
# 6285         0
# 6286         0
# 6287         1
#
# [6288 rows x 1 columns]

# %%
plt.plot(df['standing'])
plt.show()

# %%
import ruptures as rpt

# %%
test = np.array(df['standing'])
test
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=uint8)

# %%
algo = rpt.Pelt(model="rbf").fit(test)
result = algo.predict(pen=5)

# %%
rpt.display(test, [], result)
plt.show()

# %%
result
# Out:
# [215,
#  1050,
#  2075,
#  2105,
#  3190,
#  3370,
#  3575,
#  4040,
#  4375,
#  5005,
#  5310,
#  5750,
#  6275,
#  6288]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\YASHVA~1\AppData\Local\Temp/ipykernel_9928/2315009084.py in <module>
# ----> 1 test[215]
#
# NameError: name 'test' is not defined
